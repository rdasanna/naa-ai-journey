# %%
print("Hello, Data Engineering!")
print("I am a Senior PM turning AI/Data Engineer.")

name = "Rajesh Dasanna"
years_experience = 20
industry = "Telecommunications"

print(f"\nName: {name}")
print(f"Experience: {years_experience} years in {industry}")
print(f"Goal: Hands-on AI/Data Engineer")
# Out:
# Hello, Data Engineering!
# I am a Senior PM turning AI/Data Engineer.
#
# Name: Rajesh Dasanna
# Experience: 20 years in Telecommunications
# Goal: Hands-on AI/Data Engineer
